# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0.1, 1, 0.1)

# %%
y = 2 * np.log(1.25 / 0.1) / np.square(x)

# %%
plt.title("delta=0.1")
plt.plot(x, y)

# %%
x = np.arange(0.1, 1, 0.1)

# %%
y = 2 * np.log(1.25 / x) / np.square(0.1)

# %%
plt.title("epsilon=0.1")
plt.plot(x, y)

# %%
x = np.arange(-50, 50, 0.01)

# %%
scale - 10
y = (1 / 2*scale) * np.exp(-abs(x)/scale)

# %%
plt.plot(x, y)

# %%
x = np.arange(-20, 20, 0.01)

# %%
y = (2*np.exp(-x)) / pow((1+np.exp(-x)),2)

# %%
plt.plot(x, y)
